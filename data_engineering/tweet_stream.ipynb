# %% [markdown]
# ### Stream Tweets with Tweetpy

# %%
#Import the necessary methods from tweepy library
from tweepy.streaming import StreamListener
from tweepy import OAuthHandler
from tweepy import Stream

#Variables that contains the user credentials to access Twitter API 
access_token = "2267778415-tGUdixbdAkL7JARvC6EvOMOe0jawkDRXo6zXFkv"
access_token_secret = "BTH6PN4WdNNmBvF55eBeQ4t4V4i5wJOhWASrw8aot3XhC"
consumer_key = "R555aBqP5qy0dNGML3J8pEgzV"
consumer_secret = "uxtqGwtWZl0EcLX0RhG6ljbgneqKm9V2736rsSbGdbmcnWWpqy"


#This is a basic listener that just prints received tweets to stdout.
class StdOutListener(StreamListener):
    def on_data(self, data):
        print data
        return True

    def on_error(self, status):
        print status

# %%
if __name__ == '__main__':
    #This handles Twitter authetification and the connection to Twitter Streaming API
    l = StdOutListener()
    auth = OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token, access_token_secret)
    stream = Stream(auth, l)

    #This line filter Twitter Streams to capture data by the keywords: 'python', 'javascript', 'ruby'
    stream.filter(track=['python', 'javascript', 'ruby'])
# Out:
# {"created_at":"Tue Feb 13 12:11:21 +0000 2018","id":963385101475368960,"id_str":"963385101475368960","text":"RT @machine_tuts: Python Machine Learning - Part 1\n\n\u261e https:\/\/t.co\/xfRXPXGsJH\n\n#MachineLearning #TensorFlow https:\/\/t.co\/lYfNRztRS6","source":"\u003ca href=\"https:\/\/www.google.com\" rel=\"nofollow\"\u003ert_bot387\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":535783927,"id_str":"535783927","name":"Tsundukani Makhubela","screen_name":"Tsundu_Mak","location":"South Africa","url":"https:\/\/medium.com\/@Tsundu_Mak","description":"If your dreams don't scare you, they're not big enough... Introvert, a bit eccentric \ud83d\ude44, AI enthusiast & I dream in Python!","translator_type":"none","protected":false,"verified":false,"followers_count":1396,"friends_count":61,"listed_count":39,"favourites_count":7185,"statuses_count":35425,"created_at":"Sat Mar 24 22:49:56 +0000 2012","utc_offset":-28800,"time_zone":"Pacific Time (US & Canada)","geo_enabled":true,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"BADFCD","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme12\/bg.gif","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme12\/bg.gif","profile_background_tile":true,"profile_link_color":"FFFFFF","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"FFF7CC","profile_text_color":"0C3E53","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/875249696146640899\/HsYe2n-A_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/875249696146640899\/HsYe2n-A_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/535783927\/1508827578","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Mon Feb 12 19:50:16 +0000 2018","id":963138204533690368,"id_str":"963138204533690368","text":"Python Machine Learning - Part 1\n\n\u261e https:\/\/t.co\/xfRXPXGsJH\n\n#MachineLearning #TensorFlow https:\/\/t.co\/lYfNRztRS6","display_text_range":[0,89],"source":"\u003ca href=\"https:\/\/ifttt.com\" rel=\"nofollow\"\u003eIFTTT\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":727791724299354114,"id_str":"727791724299354114","name":"MachineLearning Tuts","screen_name":"machine_tuts","location":"Worldwide","url":"http:\/\/codek.tv\/v\/xmvEGS5Xbpg","description":"Here to share tutorials, courses, books, events... related to Machine Learning,  Data Science #TensorFlow #Bigdata #DataMining #DeepLearning  #Analytics","translator_type":"none","protected":false,"verified":false,"followers_count":191,"friends_count":215,"listed_count":10,"favourites_count":1,"statuses_count":910,"created_at":"Wed May 04 09:27:23 +0000 2016","utc_offset":-28800,"time_zone":"Pacific Time (US & Canada)","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/739664889271046144\/w3Wkzoz5_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/739664889271046144\/w3Wkzoz5_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/727791724299354114\/1465184707","default_profile ...
#
# {"created_at":"Tue Feb 13 12:11:22 +0000 2018","id":963385103371120640,"id_str":"963385103371120640","text":"RT @AlessiaMorani: Io comunque non sottovaluto l\u2019egittologa #Meloni dai tempi del voto su #Ruby nipote di #Mubarak  https:\/\/t.co\/N29Y6EBxcq","source":"\u003ca href=\"http:\/\/twitter.com\" rel=\"nofollow\"\u003eTwitter Web Client\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":402174719,"id_str":"402174719","name":"Roberto Mattiazzi","screen_name":"RobertoMattiaz1","location":"Valeggio sul Mincio","url":"http:\/\/www.lataiadela.wordpress.com","description":"Teigwarenhersteller. Hersteller des ber\u00fchmten Tortellini aus Valeggio. LaTaiadela: die Tortellino mit einem Klick.","translator_type":"none","protected":false,"verified":false,"followers_count":457,"friends_count":1020,"listed_count":38,"favourites_count":1264,"statuses_count":15348,"created_at":"Mon Oct 31 17:23:06 +0000 2011","utc_offset":null,"time_zone":null,"geo_enabled":true,"lang":"it","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\/\/pbs.twimg.com\/profile_background_images\/678891596\/73e0efa0e0e1dc7d410b8420774c08ae.jpeg","profile_background_image_url_https":"https:\/\/pbs.twimg.com\/profile_background_images\/678891596\/73e0efa0e0e1dc7d410b8420774c08ae.jpeg","profile_background_tile":true,"profile_link_color":"0084B4","profile_sidebar_border_color":"FFFFFF","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/1673441481\/Torre_200x300_bordi_x_avatar_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/1673441481\/Torre_200x300_bordi_x_avatar_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/402174719\/1402505968","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Tue Feb 13 11:20:04 +0000 2018","id":963372195404709888,"id_str":"963372195404709888","text":"Io comunque non sottovaluto l\u2019egittologa #Meloni dai tempi del voto su #Ruby nipote di #Mubarak  https:\/\/t.co\/N29Y6EBxcq","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":429312499,"id_str":"429312499","name":"Alessia Morani","screen_name":"AlessiaMorani","location":"Pesaro e Urbino, Marche","url":"https:\/\/www.facebook.com\/alessiamoranipd","description":"Deputata e vicepresidente del gruppo Pd, avvocato, tifosa del Milan...tranquilli non ho altri difetti :-)","translator_type":"none","protected":false,"verified":true,"followers_count":18895,"friends_count":4892,"listed_count":228,"favourites_count":11528,"statuses_count":9357,"created_at":"Mon Dec 05 20:33:29 +0000 2011","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"it","contributors_enabled":false,"is_translator":false,"profile_background_color":"C0DEED","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/531105483365838848\/SUv-VIW0_normal.jpeg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/53110548336 ...
# {"created_at":"Tue Feb 13 12:11:23 +0000 2018","id":963385109251543040,"id_str":"963385109251543040","text":"Ruby on Rails   bugs:  Ruby on Rails   bugs Ruby on Rails   bugs Ruby on Rails   bugs https:\/\/t.co\/GA2C3tY6Oq","source":"\u003ca href=\"https:\/\/freelance-ekr990011.c9users.io\/\" rel=\"nofollow\"\u003eRail Job Hub\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":849370429794004993,"id_str":"849370429794004993","name":"Rails Job Hub","screen_name":"RailsJobHub","location":null,"url":null,"description":"Aggregating Rails, Ruby, and Web Scrapping Jobs all in one site.  Saving Rails developers time and effort.","translator_type":"none","protected":false,"verified":false,"followers_count":263,"friends_count":55,"listed_count":8,"favourites_count":1,"statuses_count":35606,"created_at":"Tue Apr 04 21:17:45 +0000 2017","utc_offset":null,"time_zone":null,"geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_background_color":"F5F8FA","profile_background_image_url":"","profile_background_image_url_https":"","profile_background_tile":false,"profile_link_color":"1DA1F2","profile_sidebar_border_color":"C0DEED","profile_sidebar_fill_color":"DDEEF6","profile_text_color":"333333","profile_use_background_image":true,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/850807160279777280\/QaSabvZj_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/850807160279777280\/QaSabvZj_normal.jpg","default_profile":true,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"is_quote_status":false,"quote_count":0,"reply_count":0,"retweet_count":0,"favorite_count":0,"entities":{"hashtags":[],"urls":[{"url":"https:\/\/t.co\/GA2C3tY6Oq","expanded_url":"https:\/\/goo.gl\/pqZ8DF","display_url":"goo.gl\/pqZ8DF","indices":[86,109]}],"user_mentions":[],"symbols":[]},"favorited":false,"retweeted":false,"possibly_sensitive":false,"filter_level":"low","lang":"en","timestamp_ms":"1518523883532"}
#
# {"created_at":"Tue Feb 13 12:11:24 +0000 2018","id":963385113437442048,"id_str":"963385113437442048","text":"RT @itanimeirl: Ruby taking suggestions https:\/\/t.co\/L7flbD9HPE","source":"\u003ca href=\"http:\/\/twitter.com\" rel=\"nofollow\"\u003eTwitter Web Client\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2884432582,"id_str":"2884432582","name":"\u30b8\u30e7\u30a8\u30eb \u25b3","screen_name":"Joel_10_10","location":"\u00f1","url":"http:\/\/xn--ida.com","description":"\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1\u00f1","translator_type":"regular","protected":false,"verified":false,"followers_count":270,"friends_count":41,"listed_count":4,"favourites_count":645,"statuses_count":36427,"created_at":"Wed Nov 19 17:30:09 +0000 2014","utc_offset":0,"time_zone":"London","geo_enabled":false,"lang":"es","contributors_enabled":false,"is_translator":false,"profile_background_color":"000000","profile_background_image_url":"http:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_image_url_https":"https:\/\/abs.twimg.com\/images\/themes\/theme1\/bg.png","profile_background_tile":false,"profile_link_color":"91D2FA","profile_sidebar_border_color":"000000","profile_sidebar_fill_color":"000000","profile_text_color":"000000","profile_use_background_image":false,"profile_image_url":"http:\/\/pbs.twimg.com\/profile_images\/963217407572631553\/j34xT2vf_normal.jpg","profile_image_url_https":"https:\/\/pbs.twimg.com\/profile_images\/963217407572631553\/j34xT2vf_normal.jpg","profile_banner_url":"https:\/\/pbs.twimg.com\/profile_banners\/2884432582\/1506706648","default_profile":false,"default_profile_image":false,"following":null,"follow_request_sent":null,"notifications":null},"geo":null,"coordinates":null,"place":null,"contributors":null,"retweeted_status":{"created_at":"Tue Feb 13 11:35:14 +0000 2018","id":963376013219577856,"id_str":"963376013219577856","text":"Ruby taking suggestions https:\/\/t.co\/L7flbD9HPE","display_text_range":[0,23],"source":"\u003ca href=\"http:\/\/itunes.apple.com\/us\/app\/twitter\/id409789998?mt=12\" rel=\"nofollow\"\u003eTwitter for Mac\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":null,"in_reply_to_status_id_str":null,"in_reply_to_user_id":null,"in_reply_to_user_id_str":null,"in_reply_to_screen_name":null,"user":{"id":2634602088,"id_str":"2634602088","name":"\uff21\uff2e\uff29\uff2d\uff25\ud83c\udf8e\uff29\uff32\uff2c","screen_name":"itanimeirl","location":null,"url":null,"description":"tweeting the hot posts from r\/anime_irl and r\/Animemes by @r0an | for source, context: @itanimecontext2","translator_type":"regular","protected":false,"verified":false,"followers_count":57944,"friends_count":87,"listed_count":245,"favourites_count":68,"statuses_count":13875,"created_at":"Sun Jul 13 04:06:30 +0000 2014","utc_offset":32400,"time_zone":"Tokyo","geo_enabled":false,"lang":"en","contributors_enabled":false,"is_translator":false,"profile_backgroun ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-0e082910a103> in <module>()
#       8
#       9     #This line filter Twitter Streams to capture data by the keywords: 'python', 'javascript', 'ruby'
# ---> 10     stream.filter(track=['python', 'javascript', 'ruby'])
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/site-packages/tweepy/streaming.pyc in filter(self, follow, track, async, locations, stall_warnings, languages, encoding, filter_level)
#     443         self.session.params = {'delimited': 'length'}
#     444         self.host = 'stream.twitter.com'
# --> 445         self._start(async)
#     446
#     447     def sitestream(self, follow, stall_warnings=False,
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/site-packages/tweepy/streaming.pyc in _start(self, async)
#     359             self._thread.start()
#     360         else:
# --> 361             self._run()
#     362
#     363     def on_closed(self, resp):
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/site-packages/tweepy/streaming.pyc in _run(self)
#     261                     self.snooze_time = self.snooze_time_step
#     262                     self.listener.on_connect()
# --> 263                     self._read_loop(resp)
#     264             except (Timeout, ssl.SSLError) as exc:
#     265                 # This is still necessary, as a SSLError can actually be
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/site-packages/tweepy/streaming.pyc in _read_loop(self, resp)
#     311             length = 0
#     312             while not resp.raw.closed:
# --> 313                 line = buf.read_line().strip()
#     314                 if not line:
#     315                     self.listener.keep_alive()  # keep-alive new lines are expected
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/site-packages/tweepy/streaming.pyc in read_line(self, sep)
#     177             else:
#     178                 start = len(self._buffer)
# --> 179             self._buffer += self._stream.read(self._chunk_size)
#     180
#     181     def _pop(self, length):
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/site-packages/urllib3/response.pyc in read(self, amt, decode_content, cache_content)
#     382             else:
#     383                 cache_content = False
# --> 384                 data = self._fp.read(amt)
#     385                 if amt != 0 and not data:  # Platform-specific: Buggy versions of Python.
#     386                     # Close the connection when no data is returned
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/httplib.pyc in read(self, amt)
#     571
#     572         if self.chunked:
# --> 573             return self._read_chunked(amt)
#     574
#     575         if amt is None:
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/httplib.pyc in _read_chunked(self, amt)
#     613         while True:
#     614             if chunk_left is None:
# --> 615                 line = self.fp.readline(_MAXLINE + 1)
#     616                 if len(line) > _MAXLINE:
#     617                     raise LineTooLong("chunk size")
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/socket.pyc in readline(self, size)
#     478             while True:
#     479                 try:
# --> 480                     data = self._sock.recv(self._rbufsize)
#     481                 except error, e:
#     482                     if e.args[0] == EINTR:
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/site-packages/urllib3/contrib/pyopenssl.pyc in recv(self, *args, **kwargs)
#     268                 raise
#     269         except OpenSSL.SSL.WantReadError:
# --> 270             rd = util.wait_for_read(self.socket, self.socket.gettimeout())
#     271             if not rd:
#     272                 raise timeout('The read operation timed out')
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/site-packages/urllib3/util/wait.pyc in wait_for_read(socks, timeout)
#      31     or optionally a single socket if passed in. Returns a list of
#      32     sockets that can be read from immediately. """
# ---> 33     return _wait_for_io_events(socks, EVENT_READ, timeout)
#      34
#      35
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/site-packages/urllib3/util/wait.pyc in _wait_for_io_events(socks, events, timeout)
#      24             selector.register(sock, events)
#      25         return [key[0].fileobj for key in
# ---> 26                 selector.select(timeout) if key[1] & events]
#      27
#      28
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/site-packages/urllib3/util/selectors.pyc in select(self, timeout)
#     511
#     512             kevent_list = _syscall_wrapper(self._kqueue.control, True,
# --> 513                                            None, max_events, timeout)
#     514
#     515             for kevent in kevent_list:
#
# /Users/jeffreyhsu/anaconda3/envs/py27/lib/python2.7/site-packages/urllib3/util/selectors.pyc in _syscall_wrapper(func, recalc_timeout, *args, **kwargs)
#      92         while result is _SYSCALL_SENTINEL:
#      93             try:
# ---> 94                 result = func(*args, **kwargs)
#      95             # OSError is thrown by select.select
#      96             # IOError is thrown by select.epoll.poll
#
# KeyboardInterrupt:

# %%
class parse_and_store():
    def __init__(self, init_i):
        self.init_i = init_i
        
    def run(self):
        streamparse()
